# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          Date   Time Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-09-18  17:00  WSL  Matchweek 2  Sun  Away      L  1.0  2.0
# 1  2022-09-25  16:00  WSL  Matchweek 3  Sun  Home      W  2.0  0.0
# 2  2022-09-28  19:05  WSL  Matchweek 1  Wed  Home      W  3.0  1.0
# 3  2022-10-16  13:00  WSL  Matchweek 4  Sun  Away      W  3.0  1.0
# 5  2022-10-23  18:45  WSL  Matchweek 5  Sun  Away      W  2.0  0.0
#
#           Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 0        Liverpool  ...  Match Report    NaN   9.0  3.0  17.2  0.0  1     1
# 1  Manchester City  ...  Match Report    NaN  11.0  2.0  20.3  0.0  1     1
# 2         West Ham  ...  Match Report    NaN  20.0  7.0  15.1  0.0  0     1
# 3          Everton  ...  Match Report    NaN  21.0  7.0  17.3  0.0  1     1
# 5         Brighton  ...  Match Report    NaN  21.0  9.0  16.0  0.0  0     0
#
#    Season           Team
# 0    2024  Chelsea Women
# 1    2024  Chelsea Women
# 2    2024  Chelsea Women
# 3    2024  Chelsea Women
# 5    2024  Chelsea Women
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (964, 27)

# %%
matches["Team"].value_counts()
# Out:
# Manchester City Women             82
# Brighton and Hove Albion Women    82
# Chelsea Women                     81
# Arsenal Women                     81
# Manchester United Women           80
# Everton Women                     80
# West Ham United Women             80
# Tottenham Women                   80
# Reading Women                     80
# Aston Villa Women                 66
# Birmingham City Women             56
# Leicester City Women              44
# Liverpool Women                   36
# Bristol City Women                36
# Name: Team, dtype: int64

# %%
matches["Round"].value_counts()
# Out:
# Regular season    174
# Matchweek 14       36
# Matchweek 22       36
# Matchweek 21       36
# Matchweek 19       36
# Matchweek 18       36
# Matchweek 20       36
# Matchweek 12       36
# Matchweek 17       36
# Matchweek 16       36
# Matchweek 15       36
# Matchweek 2        36
# Matchweek 3        36
# Matchweek 10       36
# Matchweek 9        36
# Matchweek 8        36
# Matchweek 7        36
# Matchweek 6        36
# Matchweek 5        36
# Matchweek 4        36
# Matchweek 1        36
# Matchweek 13       36
# Matchweek 11       34
# Name: Round, dtype: int64

# %%
matches.dtypes
# Out:
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF              float64
# GA              float64
# Opponent         object
# xG              float64
# xGA             float64
# Poss            float64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Notes           float64
# Sh              float64
# SoT             float64
# Dist            float64
# FK              float64
# PK                int64
# PKatt             int64
# Season            int64
# Team             object
# dtype: object

# %%
matches["Date"] = pd.to_datetime(matches["Date"])

# %%
matches.dtypes
# Out:
# Date            datetime64[ns]
# Time                    object
# Comp                    object
# Round                   object
# Day                     object
# Venue                   object
# Result                  object
# GF                     float64
# GA                     float64
# Opponent                object
# xG                     float64
# xGA                    float64
# Poss                   float64
# Attendance             float64
# Captain                 object
# Formation               object
# Referee                 object
# Match Report            object
# Notes                  float64
# Sh                     float64
# SoT                    float64
# Dist                   float64
# FK                     float64
# PK                       int64
# PKatt                    int64
# Season                   int64
# Team                    object
# dtype: object

# %%
matches["Venue_Code"] = matches["Venue"].astype("category").cat.codes

# %%
matches["Opp_Code"] = matches["Opponent"].astype("category").cat.codes

# %%
matches["Hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["Day_Code"] = matches["Date"].dt.dayofweek

# %%
matches["Target"] = (matches["Result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["Date"] < '2023-01-01']

# %%
test = matches[matches["Date"] > '2023-01-01']

# %%
predictors = ["Venue_Code", "Opp_Code", "Hour", "Day_Code"]

# %%
rf.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["Target"], preds)

# %%
acc
# Out:
# 0.551948051948052

# %%
combined = pd.DataFrame(dict(actual=test["Target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           65  25
# 1           44  20

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["Target"], preds)
# Out:
# 0.4444444444444444

# %% [markdown]
# Improving predictors with rolling averages

# %%
grouped_matches = matches.groupby("Team")

# %%
group = grouped_matches.get_group("Chelsea Women")

# %%
group
# Out:
#          Date   Time Comp           Round  Day Venue Result   GF   GA  \
# 0  2022-09-18  17:00  WSL     Matchweek 2  Sun  Away      L  1.0  2.0
# 1  2022-09-25  16:00  WSL     Matchweek 3  Sun  Home      W  2.0  0.0
# 2  2022-09-28  19:05  WSL     Matchweek 1  Wed  Home      W  3.0  1.0
# 3  2022-10-16  13:00  WSL     Matchweek 4  Sun  Away      W  3.0  1.0
# 5  2022-10-23  18:45  WSL     Matchweek 5  Sun  Away      W  2.0  0.0
# ..        ...    ...  ...             ...  ...   ...    ...  ...  ...
# 10 2020-01-12  14:00  WSL  Regular season  Sun  Home      W  6.0  1.0
# 11 2020-01-19  14:00  WSL  Regular season  Sun  Away      W  4.0  1.0
# 12 2020-02-02  14:00  WSL  Regular season  Sun  Home      W  8.0  0.0
# 13 2020-02-12  19:00  WSL  Regular season  Wed  Home      W  2.0  0.0
# 14 2020-02-23  14:00  WSL  Regular season  Sun  Away      D  3.0  3.0
#
#            Opponent  ...   FK  PK  PKatt  Season           Team Venue_Code  \
# 0         Liverpool  ...  0.0   1      1    2024  Chelsea Women          0
# 1   Manchester City  ...  0.0   1      1    2024  Chelsea Women          1
# 2          West Ham  ...  0.0   0      1    2024  Chelsea Women          1
# 3           Everton  ...  0.0   1      1    2024  Chelsea Women          0
# 5          Brighton  ...  0.0   0      0    2024  Chelsea Women          0
# ..              ...  ...  ...  ..    ...     ...            ...        ...
# 10     Bristol City  ...  0.0   0      0    2021  Chelsea Women          1
# 11          Arsenal  ...  0.0   0      0    2021  Chelsea Women          0
# 12         West Ham  ...  2.0   0      0    2021  Chelsea Women          1
# 13  Birmingham City  ...  0.0   0      0    2021  Chelsea Women          1
# 14  Manchester City  ...  0.0   0      0    2021  Chelsea Women          0
#
#    Opp_Code Hour  Day_Code  Target
# 0         8   17         6       0
# 1         9   16         6       1
# 2        13   19         2       1
# 3         6   13         6       1
# 5         3   18         6       1
# ..      ...  ...       ...     ...
# 10        4   14         6       1
# 11        0   14         6       1
# 12       13   14         6       1
# 13        2   19         2       1
# 14        9   14         6       0
#
# [81 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("Date")
  rolling_stats = group[cols].rolling(3, closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time Comp           Round  Day Venue Result   GF   GA  \
# 3  2019-10-13  15:00  WSL  Regular season  Sun  Home      W  2.0  1.0
# 4  2019-10-27  15:00  WSL  Regular season  Sun  Away      W  3.0  1.0
# 5  2019-11-17  14:00  WSL  Regular season  Sun  Home      W  1.0  0.0
# 6  2019-11-24  14:45  WSL  Regular season  Sun  Away      W  6.0  0.0
# 7  2019-12-08  12:00  WSL  Regular season  Sun  Home      W  2.0  1.0
# ..        ...    ...  ...             ...  ...   ...    ...  ...  ...
# 27 2023-05-07  18:45  WSL    Matchweek 20  Sun  Home      W  7.0  0.0
# 28 2023-05-10  19:00  WSL    Matchweek 18  Wed  Home      W  6.0  0.0
# 29 2023-05-17  20:15  WSL    Matchweek 19  Wed  Away      W  4.0  0.0
# 30 2023-05-21  12:30  WSL    Matchweek 21  Sun  Home      W  2.0  0.0
# 31 2023-05-27  14:30  WSL    Matchweek 22  Sat  Away      W  3.0  0.0
#
#            Opponent  ...  Day_Code  Target  GF_rolling  GA_rolling Sh_rolling  \
# 3           Arsenal  ...         6       1    2.000000    0.333333  21.333333
# 4          West Ham  ...         6       1    2.333333    0.666667  22.000000
# 5    Manchester Utd  ...         6       1    3.000000    0.666667  24.666667
# 6   Birmingham City  ...         6       1    2.000000    0.666667  19.333333
# 7   Manchester City  ...         6       1    3.333333    0.333333  17.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 27          Everton  ...         6       1    1.666667    1.000000  16.000000
# 28   Leicester City  ...         2       1    4.000000    0.333333  18.666667
# 29         West Ham  ...         2       1    5.000000    0.333333  21.333333
# 30          Arsenal  ...         6       1    5.666667    0.000000  19.666667
# 31          Reading  ...         5       1    4.000000    0.000000  19.666667
#
#    SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 3     8.333333    16.133333   0.000000    0.000000       0.000000
# 4     8.333333    17.200000   0.333333    0.000000       0.000000
# 5    10.000000    17.366667   0.333333    0.000000       0.000000
# 6     7.000000    18.766667   0.333333    0.333333       0.333333
# 7     8.333333    15.866667   0.333333    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 27    5.333333    16.433333   0.333333    0.000000       0.000000
# 28    7.666667    14.466667   0.333333    0.000000       0.000000
# 29    9.000000    14.333333   0.333333    0.000000       0.000000
# 30    9.666667    13.066667   0.000000    0.000000       0.000000
# 31    8.333333    13.566667   0.000000    0.000000       0.000000
#
# [78 rows x 40 columns]

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                Date   Time Comp           Round  Day Venue  \
# Team
# Arsenal Women         5  2019-10-13  15:00  WSL  Regular season  Sun  Away
#                       7  2019-10-27  14:30  WSL  Regular season  Sun  Home
#                       9  2019-11-17  15:00  WSL  Regular season  Sun  Away
#                       10 2019-11-24  14:00  WSL  Regular season  Sun  Home
#                       11 2019-12-01  12:30  WSL  Regular season  Sun  Home
# ...                             ...    ...  ...             ...  ...   ...
# West Ham United Women 17 2023-04-23  18:45  WSL    Matchweek 18  Sun  Away
#                       18 2023-05-07  14:00  WSL    Matchweek 20  Sun  Away
#                       19 2023-05-17  20:15  WSL    Matchweek 19  Wed  Home
#                       20 2023-05-21  15:00  WSL    Matchweek 21  Sun  Away
#                       21 2023-05-27  14:30  WSL    Matchweek 22  Sat  Home
#
#                          Result    GF   GA         Opponent  ...  Day_Code  \
# Team                                                         ...
# Arsenal Women         5       L   1.0  2.0          Chelsea  ...         6
#                       7       W   1.0  0.0  Manchester City  ...         6
#                       9       W   2.0  0.0        Tottenham  ...         6
#                       10      W   1.0  0.0        Liverpool  ...         6
#                       11      W  11.0  1.0     Bristol City  ...         6
# ...                         ...   ...  ...              ...  ...       ...
# West Ham United Women 17      L   2.0  6.0  Manchester City  ...         6
#                       18      L   0.0  1.0         Brighton  ...         6
#                       19      L   0.0  4.0          Chelsea  ...         2
#                       20      W   2.0  1.0   Leicester City  ...         6
#                       21      D   2.0  2.0        Tottenham  ...         5
#
#                           Target  GF_rolling  GA_rolling Sh_rolling  \
# Team
# Arsenal Women         5        0    2.333333    0.333333  16.666667
#                       7        1    2.000000    0.666667  13.333333
#                       9        1    2.000000    0.666667   9.000000
#                       10       1    1.333333    0.666667  11.000000
#                       11       1    1.333333    0.000000  14.000000
# ...                          ...         ...         ...        ...
# West Ham United Women 17       0    0.333333    2.000000   6.666667
#                       18       0    0.666667    3.333333   7.000000
#                       19       0    0.666667    2.333333   5.666667
#                       20       1    0.666667    3.666667   6.000000
#                       21       0    0.666667    2.000000   4.333333
#
#                          SoT_rolling Dist_rolling FK_rolling  PK_rolling  \
# Team
# Arsenal Women         5     6.000000    14.933333   0.000000    0.000000
#                       7     5.333333    15.233333   0.000000    0.000000
#                       9     3.666667    17.100000   0.000000    0.000000
#                       10    3.000000    17.866667   0.333333    0.000000
#                       11    2.666667    18.333333   0.333333    0.000000
# ...                              ...          ...        ...         ...
# West Ham United Women 17    3.000000    19.533333   0.333333    0.000000
#                       18    2.666667    19.233333   0.333333    0.000000
#                       19    1.333333    19.300000   0.000000    0.000000
#                       20    1.666667    16.033333   0.000000    0.000000
#                       21    1.000000    19.333333   0.000000    0.333333
#
#                           PKatt_rolling
# Team
# Arsenal Women         5        0.000000
#                       7        0.000000
#                       9        0.000000
#                       10       0.000000
#                       11       0.000000
# ...                                 ...
# West Ham United Women 17       0.000000
#                       18       0.000000
#                       19       0.000000
#                       20       0.000000
#                       21       0.333333
#
# [919 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('Team')

# %%
matches_rolling
# Out:
#          Date   Time Comp           Round  Day Venue Result    GF   GA  \
# 5  2019-10-13  15:00  WSL  Regular season  Sun  Away      L   1.0  2.0
# 7  2019-10-27  14:30  WSL  Regular season  Sun  Home      W   1.0  0.0
# 9  2019-11-17  15:00  WSL  Regular season  Sun  Away      W   2.0  0.0
# 10 2019-11-24  14:00  WSL  Regular season  Sun  Home      W   1.0  0.0
# 11 2019-12-01  12:30  WSL  Regular season  Sun  Home      W  11.0  1.0
# ..        ...    ...  ...             ...  ...   ...    ...   ...  ...
# 17 2023-04-23  18:45  WSL    Matchweek 18  Sun  Away      L   2.0  6.0
# 18 2023-05-07  14:00  WSL    Matchweek 20  Sun  Away      L   0.0  1.0
# 19 2023-05-17  20:15  WSL    Matchweek 19  Wed  Home      L   0.0  4.0
# 20 2023-05-21  15:00  WSL    Matchweek 21  Sun  Away      W   2.0  1.0
# 21 2023-05-27  14:30  WSL    Matchweek 22  Sat  Home      D   2.0  2.0
#
#            Opponent  ...  Day_Code  Target  GF_rolling  GA_rolling Sh_rolling  \
# 5           Chelsea  ...         6       0    2.333333    0.333333  16.666667
# 7   Manchester City  ...         6       1    2.000000    0.666667  13.333333
# 9         Tottenham  ...         6       1    2.000000    0.666667   9.000000
# 10        Liverpool  ...         6       1    1.333333    0.666667  11.000000
# 11     Bristol City  ...         6       1    1.333333    0.000000  14.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 17  Manchester City  ...         6       0    0.333333    2.000000   6.666667
# 18         Brighton  ...         6       0    0.666667    3.333333   7.000000
# 19          Chelsea  ...         2       0    0.666667    2.333333   5.666667
# 20   Leicester City  ...         6       1    0.666667    3.666667   6.000000
# 21        Tottenham  ...         5       0    0.666667    2.000000   4.333333
#
#    SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 5     6.000000    14.933333   0.000000    0.000000       0.000000
# 7     5.333333    15.233333   0.000000    0.000000       0.000000
# 9     3.666667    17.100000   0.000000    0.000000       0.000000
# 10    3.000000    17.866667   0.333333    0.000000       0.000000
# 11    2.666667    18.333333   0.333333    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 17    3.000000    19.533333   0.333333    0.000000       0.000000
# 18    2.666667    19.233333   0.333333    0.000000       0.000000
# 19    1.333333    19.300000   0.000000    0.000000       0.000000
# 20    1.666667    16.033333   0.000000    0.000000       0.000000
# 21    1.000000    19.333333   0.000000    0.333333       0.333333
#
# [919 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           Date   Time Comp           Round  Day Venue Result    GF   GA  \
# 0   2019-10-13  15:00  WSL  Regular season  Sun  Away      L   1.0  2.0
# 1   2019-10-27  14:30  WSL  Regular season  Sun  Home      W   1.0  0.0
# 2   2019-11-17  15:00  WSL  Regular season  Sun  Away      W   2.0  0.0
# 3   2019-11-24  14:00  WSL  Regular season  Sun  Home      W   1.0  0.0
# 4   2019-12-01  12:30  WSL  Regular season  Sun  Home      W  11.0  1.0
# ..         ...    ...  ...             ...  ...   ...    ...   ...  ...
# 914 2023-04-23  18:45  WSL    Matchweek 18  Sun  Away      L   2.0  6.0
# 915 2023-05-07  14:00  WSL    Matchweek 20  Sun  Away      L   0.0  1.0
# 916 2023-05-17  20:15  WSL    Matchweek 19  Wed  Home      L   0.0  4.0
# 917 2023-05-21  15:00  WSL    Matchweek 21  Sun  Away      W   2.0  1.0
# 918 2023-05-27  14:30  WSL    Matchweek 22  Sat  Home      D   2.0  2.0
#
#             Opponent  ...  Day_Code  Target  GF_rolling  GA_rolling  \
# 0            Chelsea  ...         6       0    2.333333    0.333333
# 1    Manchester City  ...         6       1    2.000000    0.666667
# 2          Tottenham  ...         6       1    2.000000    0.666667
# 3          Liverpool  ...         6       1    1.333333    0.666667
# 4       Bristol City  ...         6       1    1.333333    0.000000
# ..               ...  ...       ...     ...         ...         ...
# 914  Manchester City  ...         6       0    0.333333    2.000000
# 915         Brighton  ...         6       0    0.666667    3.333333
# 916          Chelsea  ...         2       0    0.666667    2.333333
# 917   Leicester City  ...         6       1    0.666667    3.666667
# 918        Tottenham  ...         5       0    0.666667    2.000000
#
#     Sh_rolling SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 0    16.666667    6.000000    14.933333   0.000000    0.000000       0.000000
# 1    13.333333    5.333333    15.233333   0.000000    0.000000       0.000000
# 2     9.000000    3.666667    17.100000   0.000000    0.000000       0.000000
# 3    11.000000    3.000000    17.866667   0.333333    0.000000       0.000000
# 4    14.000000    2.666667    18.333333   0.333333    0.000000       0.000000
# ..         ...         ...          ...        ...         ...            ...
# 914   6.666667    3.000000    19.533333   0.333333    0.000000       0.000000
# 915   7.000000    2.666667    19.233333   0.333333    0.000000       0.000000
# 916   5.666667    1.333333    19.300000   0.000000    0.000000       0.000000
# 917   6.000000    1.666667    16.033333   0.000000    0.000000       0.000000
# 918   4.333333    1.000000    19.333333   0.000000    0.333333       0.333333
#
# [919 rows x 40 columns]

# %% [markdown]
# Retraining ML model

# %%
def make_predictions(data, predictor):
  train = data[data["Date"] < '2023-01-01']
  test = data[data["Date"] > '2023-01-01']
  rf.fit(train[predictors], train["Target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test["Target"], predicted=preds), index=test.index)
  precision = precision_score(test["Target"], preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.45454545454545453

# %%
combined
# Out:
#      actual  predicted
# 65        0          0
# 66        0          1
# 67        0          0
# 68        1          0
# 69        1          1
# ..      ...        ...
# 914       0          1
# 915       0          0
# 916       0          0
# 917       1          1
# 918       0          0
#
# [154 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      actual  predicted       Date                   Team         Opponent  \
# 65        0          0 2023-01-15          Arsenal Women          Chelsea
# 66        0          1 2023-02-05          Arsenal Women         West Ham
# 67        0          0 2023-02-11          Arsenal Women  Manchester City
# 68        1          0 2023-03-08          Arsenal Women        Liverpool
# 69        1          1 2023-03-12          Arsenal Women          Reading
# ..      ...        ...        ...                    ...              ...
# 914       0          1 2023-04-23  West Ham United Women  Manchester City
# 915       0          0 2023-05-07  West Ham United Women         Brighton
# 916       0          0 2023-05-17  West Ham United Women          Chelsea
# 917       1          1 2023-05-21  West Ham United Women   Leicester City
# 918       0          0 2023-05-27  West Ham United Women        Tottenham
#
#     Result
# 65       D
# 66       D
# 67       L
# 68       W
# 69       W
# ..     ...
# 914      L
# 915      L
# 916      L
# 917      W
# 918      D
#
# [154 rows x 6 columns]

# %%
class MissingDict(dict):
  __missing__ = lambda self, key: key

map_values = {
    "Arsenal Women": "Arsenal",
    "Aston Villa Women": "Aston Villa",
    "Brighton and Hove Albion Women": "Brighton",
    "Chelsea Women": "Chelsea",
    "Everton Women": "Everton",
    "Leicester City Women": "Lecester City",
    "Liverpool Women": "Liverpool",
    "Manchester City Women": "Manchester City",
    "Manchester United Women": "Manchester Utd",
    "Reading Women": "Reading",
    "Tottenham Women": "Tottenham",
    "West Ham United Women": "West Ham"
}
mapping = MissingDict(**map_values)

# %%
combined["Team"].unique()
# Out:
# array(['Arsenal Women', 'Aston Villa Women',
#        'Brighton and Hove Albion Women', 'Chelsea Women', 'Everton Women',
#        'Leicester City Women', 'Liverpool Women', 'Manchester City Women',
#        'Manchester United Women', 'Reading Women', 'Tottenham Women',
#        'West Ham United Women'], dtype=object)

# %%
mapping["Arsenal Women"]
# Out:
# 'Arsenal'

# %%
combined["New_Team"] = combined["Team"].map(mapping)

# %%
combined
# Out:
#      actual  predicted       Date                   Team         Opponent  \
# 65        0          0 2023-01-15          Arsenal Women          Chelsea
# 66        0          1 2023-02-05          Arsenal Women         West Ham
# 67        0          0 2023-02-11          Arsenal Women  Manchester City
# 68        1          0 2023-03-08          Arsenal Women        Liverpool
# 69        1          1 2023-03-12          Arsenal Women          Reading
# ..      ...        ...        ...                    ...              ...
# 914       0          1 2023-04-23  West Ham United Women  Manchester City
# 915       0          0 2023-05-07  West Ham United Women         Brighton
# 916       0          0 2023-05-17  West Ham United Women          Chelsea
# 917       1          1 2023-05-21  West Ham United Women   Leicester City
# 918       0          0 2023-05-27  West Ham United Women        Tottenham
#
#     Result  New_Team
# 65       D   Arsenal
# 66       D   Arsenal
# 67       L   Arsenal
# 68       W   Arsenal
# 69       W   Arsenal
# ..     ...       ...
# 914      L  West Ham
# 915      L  West Ham
# 916      L  West Ham
# 917      W  West Ham
# 918      D  West Ham
#
# [154 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["Date", "New_Team"], right_on=["Date", "Opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       Date                 Team_x       Opponent_x  \
# 0           0            0 2023-01-15          Arsenal Women          Chelsea
# 1           0            1 2023-02-05          Arsenal Women         West Ham
# 2           0            0 2023-02-11          Arsenal Women  Manchester City
# 3           1            0 2023-03-08          Arsenal Women        Liverpool
# 4           1            1 2023-03-12          Arsenal Women          Reading
# ..        ...          ...        ...                    ...              ...
# 136         0            1 2023-04-23  West Ham United Women  Manchester City
# 137         0            0 2023-05-07  West Ham United Women         Brighton
# 138         0            0 2023-05-17  West Ham United Women          Chelsea
# 139         1            1 2023-05-21  West Ham United Women   Leicester City
# 140         0            0 2023-05-27  West Ham United Women        Tottenham
#
#     Result_x New_Team_x  actual_y  predicted_y  \
# 0          D    Arsenal         0            0
# 1          D    Arsenal         0            0
# 2          L    Arsenal         1            0
# 3          W    Arsenal         0            0
# 4          W    Arsenal         0            0
# ..       ...        ...       ...          ...
# 136        L   West Ham         1            1
# 137        L   West Ham         1            0
# 138        L   West Ham         1            0
# 139        W   West Ham         0            0
# 140        D   West Ham         0            1
#
#                              Team_y Opponent_y Result_y       New_Team_y
# 0                     Chelsea Women    Arsenal        D          Chelsea
# 1             West Ham United Women    Arsenal        D         West Ham
# 2             Manchester City Women    Arsenal        W  Manchester City
# 3                   Liverpool Women    Arsenal        L        Liverpool
# 4                     Reading Women    Arsenal        L          Reading
# ..                              ...        ...      ...              ...
# 136           Manchester City Women   West Ham        W  Manchester City
# 137  Brighton and Hove Albion Women   West Ham        W         Brighton
# 138                   Chelsea Women   West Ham        W          Chelsea
# 139            Leicester City Women   West Ham        L    Lecester City
# 140                 Tottenham Women   West Ham        D        Tottenham
#
# [141 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# 1    18
# 0    16
# Name: actual_x, dtype: int64

# %%
18/34
# Out:
# 0.5294117647058824
