# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/189/Womens-Super-League-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/a6a4e67d/Chelsea-Women-Stats',
#  'https://fbref.com/en/squads/9ce68f8a/Manchester-City-Women-Stats',
#  'https://fbref.com/en/squads/411b1108/Arsenal-Women-Stats',
#  'https://fbref.com/en/squads/0bbd83f6/Manchester-United-Women-Stats',
#  'https://fbref.com/en/squads/00f74a56/Liverpool-Women-Stats',
#  'https://fbref.com/en/squads/e8e4577c/Tottenham-Women-Stats',
#  'https://fbref.com/en/squads/23bce84e/Leicester-City-Women-Stats',
#  'https://fbref.com/en/squads/53157aa8/Aston-Villa-Women-Stats',
#  'https://fbref.com/en/squads/fa2752bc/Brighton-and-Hove-Albion-Women-Stats',
#  'https://fbref.com/en/squads/c4989550/Everton-Women-Stats',
#  'https://fbref.com/en/squads/52d65cea/West-Ham-United-Women-Stats',
#  'https://fbref.com/en/squads/41916f68/Bristol-City-Women-Stats']

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd

matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0].head()
# Out:
#          Date   Time Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-10-01  17:30  WSL  Matchweek 1  Sun  Home      W  2.0  1.0
# 1  2023-10-08  12:30  WSL  Matchweek 2  Sun  Away      D  1.0  1.0
# 2  2023-10-14  17:30  WSL  Matchweek 3  Sat  Home      W  2.0  0.0
# 3  2023-10-22  14:00  WSL  Matchweek 4  Sun  Home      W  4.0  2.0
# 4  2023-11-04  12:30  WSL  Matchweek 5  Sat  Away      W  6.0  0.0
#
#           Opponent   xG  xGA  Poss  Attendance        Captain Formation  \
# 0        Tottenham  2.6  2.0  55.0     14776.0   Lauren James   4-2-3-1
# 1  Manchester City  1.9  0.5  65.0      5249.0  Millie Bright   4-2-3-1
# 2         West Ham  2.4  1.0  71.0      3313.0  Millie Bright     3-4-3
# 3         Brighton  4.6  0.5  65.0      3647.0  Millie Bright     3-4-3
# 4      Aston Villa  5.4  0.7  54.0      4086.0  Millie Bright   3-4-1-2
#
#            Referee  Match Report Notes
# 0       James Bell  Match Report   NaN
# 1    Emily Heaslip  Match Report   NaN
# 2   Stacey Pearson  Match Report   NaN
# 3  Stacey Fullicks  Match Report   NaN
# 4    Abigail Byrne  Match Report   NaN

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/a6a4e67d/2023-2024/matchlogs/all_comps/shooting/Chelsea-Women-Match-Logs-All-Competitions',
#  '/en/squads/a6a4e67d/2023-2024/matchlogs/all_comps/shooting/Chelsea-Women-Match-Logs-All-Competitions',
#  '/en/squads/a6a4e67d/2023-2024/matchlogs/all_comps/shooting/Chelsea-Women-Match-Logs-All-Competitions',
#  '/en/squads/a6a4e67d/2023-2024/matchlogs/all_comps/shooting/Chelsea-Women-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Chelsea                                                       \
#          Date   Time Comp        Round  Day Venue Result   GF   GA
# 0  2023-10-01  17:30  WSL  Matchweek 1  Sun  Home      W  2.0  1.0
# 1  2023-10-08  12:30  WSL  Matchweek 2  Sun  Away      D  1.0  1.0
# 2  2023-10-14  17:30  WSL  Matchweek 3  Sat  Home      W  2.0  0.0
# 3  2023-10-22  14:00  WSL  Matchweek 4  Sun  Home      W  4.0  2.0
# 4  2023-11-04  12:30  WSL  Matchweek 5  Sat  Away      W  6.0  0.0
#
#                     ... Standard             Expected                    \
#           Opponent  ...     Dist FK PK PKatt       xG npxG npxG/Sh G-xG
# 0        Tottenham  ...     13.5  0  0     0      2.6  2.6    0.15 -0.6
# 1  Manchester City  ...     14.5  0  0     0      1.9  1.9    0.11 -0.9
# 2         West Ham  ...     16.4  2  0     0      2.4  2.4    0.13 -0.4
# 3         Brighton  ...     11.6  0  0     0      4.6  4.6    0.16 -0.6
# 4      Aston Villa  ...     11.4  0  0     0      5.4  5.4    0.22  0.6
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0    -0.6        Match Report
# 1    -0.9        Match Report
# 2    -0.4        Match Report
# 3    -0.6        Match Report
# 4     0.6        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-10-01  17:30  WSL  Matchweek 1  Sun  Home      W  2.0  1.0
# 1  2023-10-08  12:30  WSL  Matchweek 2  Sun  Away      D  1.0  1.0
# 2  2023-10-14  17:30  WSL  Matchweek 3  Sat  Home      W  2.0  0.0
# 3  2023-10-22  14:00  WSL  Matchweek 4  Sun  Home      W  4.0  2.0
# 4  2023-11-04  12:30  WSL  Matchweek 5  Sat  Away      W  6.0  0.0
#
#           Opponent  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0        Tottenham  ...  13.5   0   0      0  2.6   2.6     0.15  -0.6
# 1  Manchester City  ...  14.5   0   0      0  1.9   1.9     0.11  -0.9
# 2         West Ham  ...  16.4   2   0      0  2.4   2.4     0.13  -0.4
# 3         Brighton  ...  11.6   0   0      0  4.6   4.6     0.16  -0.6
# 4      Aston Villa  ...  11.4   0   0      0  5.4   5.4     0.22   0.6
#
#    np:G-xG  Match Report
# 0     -0.6  Match Report
# 1     -0.9  Match Report
# 2     -0.4  Match Report
# 3     -0.6  Match Report
# 4      0.6  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
shooting.shape
# Out:
# (22, 26)

# %%
years = list(range(2024,2020, -1))

# %%
years
# Out:
# [2024, 2023, 2022, 2021]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/189/Womens-Super-League-Stats"

# %%
import time
for year in years:
  data = requests.get(standings_url)
  soup = BeautifulSoup(data.text)
  standings_table = soup.select('table.stats_table')[0]

  links = [l.get("href") for l in standings_table.find_all('a')]
  links = [l for l in links if '/squads/' in l]
  team_urls = [f"https://fbref.com{l}" for l in links]

  previous_season = soup.select("a.prev")[0].get("href")
  standings_url = f"https://fbref.com/{previous_season}"

  for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

    data = requests.get(team_url)
    matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

    soup = BeautifulSoup(data.text)
    links = [l.get("href") for l in soup.find_all('a')]
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    data = requests.get(f"https://fbref.com{links[0]}")
    shooting = pd.read_html(data.text, match="Shooting")[0]
    shooting.columns = shooting.columns.droplevel()

    try:
      team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
    except ValueError:
      continue

    team_data = team_data[team_data["Comp"] == "WSL"]
    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)
    time.sleep(1)

# %%
match_df = pd.concat(all_matches)

# %%
match_df.to_csv("matches.csv")

# %%
match_df
# Out:
#           Date   Time Comp           Round  Day Venue Result   GF   GA  \
# 0   2022-09-18  17:00  WSL     Matchweek 2  Sun  Away      L    1    2
# 1   2022-09-25  16:00  WSL     Matchweek 3  Sun  Home      W    2    0
# 2   2022-09-28  19:05  WSL     Matchweek 1  Wed  Home      W    3    1
# 3   2022-10-16  13:00  WSL     Matchweek 4  Sun  Away      W    3    1
# 5   2022-10-23  18:45  WSL     Matchweek 5  Sun  Away      W    2    0
# ..         ...    ...  ...             ...  ...   ...    ...  ...  ...
# 9   2019-12-15  14:00  WSL  Regular season  Sun  Home      D  1.0  1.0
# 10  2020-01-05  14:00  WSL  Regular season  Sun  Away      L  0.0  1.0
# 11  2020-01-19  15:00  WSL  Regular season  Sun  Away      W  1.0  0.0
# 12  2020-02-13  19:00  WSL  Regular season  Thu  Home      L  2.0  3.0
# 13  2020-02-23  15:00  WSL  Regular season  Sun  Away      L  2.0  4.0
#
#            Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 0         Liverpool  ...  Match Report    NaN   9.0  3.0  17.2  0.0  1     1
# 1   Manchester City  ...  Match Report    NaN  11.0  2.0  20.3  0.0  1     1
# 2          West Ham  ...  Match Report    NaN  20.0  7.0  15.1  0.0  0     1
# 3           Everton  ...  Match Report    NaN  21.0  7.0  17.3  0.0  1     1
# 5          Brighton  ...  Match Report    NaN  21.0  9.0  16.0  0.0  0     0
# ..              ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 9           Chelsea  ...  Match Report    NaN   9.0  7.0  22.5  3.0  0     0
# 10         Brighton  ...  Match Report    NaN  13.0  1.0  20.0  2.0  0     0
# 11     Bristol City  ...  Match Report    NaN  17.0  7.0  19.3  1.0  0     0
# 12          Arsenal  ...  Match Report    NaN   4.0  3.0  19.6  0.0  0     0
# 13         West Ham  ...  Match Report    NaN  15.0  5.0  15.1  0.0  0     0
#
#    Season             Team
# 0    2024    Chelsea Women
# 1    2024    Chelsea Women
# 2    2024    Chelsea Women
# 3    2024    Chelsea Women
# 5    2024    Chelsea Women
# ..    ...              ...
# 9    2021  Liverpool Women
# 10   2021  Liverpool Women
# 11   2021  Liverpool Women
# 12   2021  Liverpool Women
# 13   2021  Liverpool Women
#
# [964 rows x 27 columns]
